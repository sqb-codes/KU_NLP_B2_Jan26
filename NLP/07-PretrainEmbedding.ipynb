# %%
# Use Pretrained Embeddings
# 2 popular pretrained models:
# 1. Google news Word2Vec (300)
# 2. GloVe (Stanford)

# %%
import gensim.downloader as api

print("Loading pretrained models:")
# model = api.load("word2vec-google-news-300")
model = api.load("glove-wiki-gigaword-100")
# Common GloVe pretrained vectors
# 1. glove-wiki-gigaword-50
# 2. glove-wiki-gigaword-100
# 3. glove-wiki-gigaword-300
# 4. glove-twitter-200
# Out:
# Loading pretrained models:
# [==================================================] 100.0% 128.1/128.1MB downloaded

# %%
print(model.similarity("artificial", "intelligence"))
# Out:
# 0.21335429

# %%
print(model.most_similar("happy", topn=15))
# Out:
# [("'m", 0.8413287401199341), ('feel', 0.8132575750350952), ("'re", 0.804808497428894), ('i', 0.7938276529312134), ("'ll", 0.7916273474693298), ('really', 0.7903971076011658), ('glad', 0.7833361029624939), ('good', 0.7821646332740784), ('we', 0.7808917164802551), ('sure', 0.7788467407226562), ('everyone', 0.7788339257240295), ("'d", 0.7784851789474487), ('proud', 0.7701813578605652), ('know', 0.7700926065444946), ('everybody', 0.7669124007225037)]
