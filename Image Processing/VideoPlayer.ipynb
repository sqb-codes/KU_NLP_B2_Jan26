# %%
# !pip install yt_dlp

# %%
import cv2
import yt_dlp

# %%
URL = "https://www.youtube.com/watch?v=JP1Ba7elMA0"
ydl_options = {
    'format': 'best[ext=mp4]'
}
with yt_dlp.YoutubeDL(ydl_options) as ydl:
    info = ydl.extract_info(URL, download=False)
    # Get video stream URL
    video_url = info['url']
    cap = cv2.VideoCapture(video_url)
    haar = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
    while True:
        # get frames from video
        ret, frame = cap.read()
        # break if video ends of fails
        if not ret:
            break
        faces = haar.detectMultiScale(frame, scaleFactor=1.3)
        for (x,y,w,h) in faces:
            cv2.rectangle(frame, (x,y), (x+w, y+h), (0,255,0), 2)
        cv2.imshow("My Camera", frame)
        key = cv2.waitKey(25) & 0xFF
        if key == 27:
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=JP1Ba7elMA0
# [youtube] JP1Ba7elMA0: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] JP1Ba7elMA0: Downloading android vr player API JSON
