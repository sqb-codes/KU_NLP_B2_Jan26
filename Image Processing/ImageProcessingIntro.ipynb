# %%
# pip install opencv-python
# cv2 - Computer Vision
import cv2

# %%
img = cv2.imread("msd.jpeg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (593, 1080, 3)

# %%
img[0]
# Out:
# array([[117,  81,  41],
#        [119,  83,  43],
#        [121,  85,  45],
#        ...,
#        [ 41,  52,  49],
#        [ 40,  51,  48],
#        [ 39,  50,  47]], shape=(1080, 3), dtype=uint8)

# %%
import matplotlib.pyplot as plt
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
# Show image window
cv2.imshow("MSD", img)

# Loop to check key press
while True:
    key = cv2.waitKey(0) & 0xFF
    
    # ESC key (27) is more reliable than 'q'
    if key == 27:
        break

cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 6
#       4 # Loop to check key press
#       5 while True:
# ----> 6     key = cv2.waitKey(0) & 0xFF
#       8     # ESC key (27) is more reliable than 'q'
#       9     if key == 27:
#
# KeyboardInterrupt:
